# %%
import sklearn.datasets as datasets
import pandas as pd
iris=datasets.load_iris()
df=pd.DataFrame(iris.data, columns=iris.feature_names)
y=iris.target

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(df,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
import sys

# !{sys.executable} -m pip install pydotplus
# !{sys.executable} -m pip install graphviz
# !{sys.executable} -m pip install pydot
# Out:
# Requirement already satisfied: pydotplus in c:\users\student\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in c:\users\student\anaconda3\lib\site-packages (from pydotplus) (2.3.1)
# Requirement already satisfied: graphviz in c:\users\student\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: pydot in c:\users\student\anaconda3\lib\site-packages (1.4.1)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\student\anaconda3\lib\site-packages (from pydot) (2.3.1)

# %%
iris = datasets.load_iris()
X = iris.data
y = iris.target
clf = DecisionTreeClassifier(random_state=0)

# Train model
model = clf.fit(X, y)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import datasets
from IPython.display import Image  
from sklearn import tree
import pydotplus
# Create DOT data
#graphviz dot language
dot_data = tree.export_graphviz(clf, out_file=None, 
                                feature_names=iris.feature_names,  
                                class_names=iris.target_names)

# Draw graph
graph = pydotplus.graph_from_dot_data(dot_data)  

# Show graph
Image(graph.create_png())

# %%
graph

# %%
dot_data
# Out:
# 'digraph Tree {\nnode [shape=box] ;\n0 [label="petal width (cm) <= 0.8\\ngini = 0.667\\nsamples = 150\\nvalue = [50, 50, 50]\\nclass = setosa"] ;\n1 [label="gini = 0.0\\nsamples = 50\\nvalue = [50, 0, 0]\\nclass = setosa"] ;\n0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;\n2 [label="petal width (cm) <= 1.75\\ngini = 0.5\\nsamples = 100\\nvalue = [0, 50, 50]\\nclass = versicolor"] ;\n0 -> 2 [labeldistance=2.5, labelangle=-45, headlabel="False"] ;\n3 [label="petal length (cm) <= 4.95\\ngini = 0.168\\nsamples = 54\\nvalue = [0, 49, 5]\\nclass = versicolor"] ;\n2 -> 3 ;\n4 [label="petal width (cm) <= 1.65\\ngini = 0.041\\nsamples = 48\\nvalue = [0, 47, 1]\\nclass = versicolor"] ;\n3 -> 4 ;\n5 [label="gini = 0.0\\nsamples = 47\\nvalue = [0, 47, 0]\\nclass = versicolor"] ;\n4 -> 5 ;\n6 [label="gini = 0.0\\nsamples = 1\\nvalue = [0, 0, 1]\\nclass = virginica"] ;\n4 -> 6 ;\n7 [label="petal width (cm) <= 1.55\\ngini = 0.444\\nsamples = 6\\nvalue = [0, 2, 4]\\nclass = virginica"] ;\n3 -> 7 ;\n8 [label="gini = 0.0\\nsamples = 3\\nvalue = [0, 0, 3]\\nclass = virginica"] ;\n7 -> 8 ;\n9 [label="petal length (cm) <= 5.45\\ngini = 0.444\\nsamples = 3\\nvalue = [0, 2, 1]\\nclass = versicolor"] ;\n7 -> 9 ;\n10 [label="gini = 0.0\\nsamples = 2\\nvalue = [0, 2, 0]\\nclass = versicolor"] ;\n9 -> 10 ;\n11 [label="gini = 0.0\\nsamples = 1\\nvalue = [0, 0, 1]\\nclass = virginica"] ;\n9 -> 11 ;\n12 [label="petal length (cm) <= 4.85\\ngini = 0.043\\nsamples = 46\\nvalue = [0, 1, 45]\\nclass = virginica"] ;\n2 -> 12 ;\n13 [label="sepal width (cm) <= 3.1\\ngini = 0.444\\nsamples = 3\\nvalue = [0, 1, 2]\\nclass = virginica"] ;\n12 -> 13 ;\n14 [label="gini = 0.0\\nsamples = 2\\nvalue = [0, 0, 2]\\nclass = virginica"] ;\n13 -> 14 ;\n15 [label="gini = 0.0\\nsamples = 1\\nvalue = [0, 1, 0]\\nclass = versicolor"] ;\n13 -> 15 ;\n16 [label="gini = 0.0\\nsamples = 43\\nvalue = [0, 0, 43]\\nclass = virginica"] ;\n12 -> 16 ;\n}'
